# %% [markdown]
# # Unblinded entorno

# %%
from funciones_navegacion import *
import os
from dotenv import load_dotenv
from PIL import Image
import google.generativeai as genai
from groq import Groq
import base64

# %%
#  Inicializar el cliente con API Key
load_dotenv()
API_KEY = os.getenv("GROQ_API_KEY")
client = Groq(api_key=API_KEY)

# %%
# Modo 1: Obtencion de una respuesta a un prompt
pregunta = "Explícame brevemente qué es una API como si tuviera 5 años."
resultado = ask_groq(prompt = pregunta)

print("🤖 Groq dice:")
print("-" * 20)
print(resultado)
# Out:
# Mode 1
# 🤖 Groq dice:
# --------------------
# Una API es como un mensajero que lleva pedidos y respuestas entre diferentes lugares. Imagina que quieres un helado. Tú le dices a un mensajero qué helado quieres y él se lo dice al dueño de la heladería. El dueño prepara el helado y se lo da al mensajero, quien te lo trae. La API es como ese mensajero, pero para computadoras, llevando pedidos y respuestas entre diferentes sitios de internet.

# %%
# Modo 2: Obtencion de una respuesta con una imagen
resultado = ask_groq(img_path='paso_peatones.jpg')

print("🤖 Groq dice:")
print("-" * 20)
print(resultado)
# Out:
# Mode 2
# 🤖 Groq dice:
# --------------------
# Peligro. Un coche negro ha invadido un paso de peatones. Detrás se ve una cola de coches esperando para seguir avanzando en el semáforo, mientras en el lado izquierdo varios coches están aparcados y dos personas con mascarilla miran hacia la izquierda.

# %%
# Modo 3: Obtencion de una respuesta especifica con un prompt y una imagen
pregunta = "Dime que tipos de animales se ven en la imagen."
resultado = ask_groq(prompt = pregunta, img_path='praderas.jpg')

print("🤖 Groq dice:")
print("-" * 20)
print(resultado)
# Out:
# Mode 3
# 🤖 Groq dice:
# --------------------
# Caballos.
